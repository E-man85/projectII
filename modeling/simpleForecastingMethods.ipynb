# %% [markdown]
# # Simple forecasting methods

# %%
# Carregar Bibliotecas
library(ggplot2)
library(forecast)
library(dplyr)
library(xts)
library(tidyverse)

# %%
path <- "https://raw.githubusercontent.com/E-man85/projectII/main/dataStaging/grainWeekMultipleVariables.csv"
df <- read.csv(path)
df <- df[, c('store_id','date', 'summed_revenue')]
rm(path)
head(df)
str(df)
dim(df)
# Out:
#   store_id date       summed_revenue
# 1 S0002    2017-01-08 1813.24
# 2 S0002    2017-01-15 1896.91
# 3 S0002    2017-01-22 7404.16
# 4 S0002    2017-01-29 2078.39
# 5 S0002    2017-02-05 1745.47
# 6 S0002    2017-02-12 2235.39
# 'data.frame':	8301 obs. of  3 variables:
#  $ store_id      : chr  "S0002" "S0002" "S0002" "S0002" ...
#  $ date          : chr  "2017-01-08" "2017-01-15" "2017-01-22" "2017-01-29" ...
#  $ summed_revenue: num  1813 1897 7404 2078 1745 ...
# [1] 8301    3

# %% [markdown]
# ## Data Preparation

# %%
# Alterar tipo da coluna date
df$date <- as.Date(df$date)
# Criar variável com lista das lojas unicas
stores <- unique(df$store_id)
# Lista para armazenar os dataframes
df_list <- list()
# Loop para criar os dataframes separados
for (store in stores) {
  # filtrar dataframe
  df_store <- df[df$store_id == store,]
  # Adicionar dataframe à lista
  df_list[[store]] <- df_store
}
# Dividir dados treino e teste
# lista para armazenar os timeseries teste e treino
df_train <- list()
df_test <- list()
# Loop para criar as séries temporais semanais e armazenar nas lista
for (t in names(df_list)) {
  data <- df_list[[t]]
  train <- head(data, -5)
  test <- tail(data, 5)
  df_train[[t]] <- train
  df_test[[t]] <- test
}
# Converter em timeseries ts cada elemento da lista
# lista para armazenar os timeseries 
ts_real <- list()
ts_train <- list()
ts_test <- list()
# Loop
for(t in names(df_list)){
    data <- df_list[[t]]
    ts <- ts(data = data$summed_revenue, frequency = 52)
    ts_real[[t]] <- ts
}
# Loop
for(t in names(df_train)){
    data <- df_train[[t]]
    ts <- ts(data = data$summed_revenue, frequency = 52)
    ts_train[[t]] <- ts
}
# Loop
for(t in names(df_test)){
    data <- df_test[[t]]
    ts <- ts(data = data$summed_revenue, frequency = 52)
    ts_test[[t]] <- ts
}
length(ts_train)
length(ts_test)
length(ts_real)
# Out:
# [1] 63
# [1] 63
# [1] 63

# %%
# Observações vs Tempo ex 3 primeiras lojas
options(repr.plot.width = 20, repr.plot.height = 4)
for (i in 1:length(ts_train)) {
  ts_name <- names(ts_train)[i]
  ts <- ts_train[[ts_name]]
  
  # Plotar a série temporal para os 3 primeiros elementos
  if (i <= 3) {
    plot <- autoplot(ts) +
      ggtitle(paste("Revenue Over Time -", ts_name)) +
      xlab("Time") +
      ylab("Revenue")
    
    # Exibir o gráfico
    print(plot)
  }
}
# Out:
# plot without title
# plot without title
# plot without title

# %%
# Decompose ts como exemplo a primeira da lista
dec <- decompose(ts_train[[1]]) 
dec
# Out:
# $x
# Time Series:
# Start = c(1, 1)
# End = c(3, 34)
# Frequency = 52
#   [1]  1813.24  1896.91  7404.16  2078.39  1745.47  2235.39  2356.01  1973.80
#   [9]  2573.37  2594.16  2064.74  2001.88  1890.32  2375.89  1903.69  1976.66
#  [17]  1344.25  1890.46  2154.86  2550.11  6097.26  3626.28  3958.66  2472.34
#  [25]  1788.50  1603.02  2122.74  1734.00  1767.14  1551.87  1641.40  2206.39
#  [33]  1865.82  1963.61  2301.41  2105.77  3587.69  2005.43  2727.31  2934.19
#  [41]  2473.18  2843.82  2153.29  2007.78  2096.73  2225.73  2083.53  2087.13
#  [49]  2396.83  2187.45  3126.87  2554.28  2232.36  2459.07  4959.87  2531.08
#  [57]  2651.46  3318.19  2792.04  4462.69  3136.89  2562.01  2032.89  2546.42
#  [65]  2000.69  2254.15  2971.12  3148.83  3013.51  3624.29  3577.06  7796.56
#  [73] 13731.16  4436.39  3603.06  4009.99  2837.63  2808.51  2346.45  2649.95
#  [81]  3068.91  2343.79  2610.58  3218.72  3206.64  2152.37  2381.59  2904.98
#  [89]  6333.15  2753.73  2741.11  3714.50  4459.90  3638.16  2588.56  2830.50
#  [97]  2561.47  2550.94  2607.10  2610.98  3123.20  3450.06  3546.61  2941.19
# [105]  3655.08  3053.83  4997.78  3580.74  4096.85  5840.03  4542.51  3683.56
# [113]  3547.58  4597.84  3984.73  3575.84  3169.98  3594.56  3648.72  3747.26
# [121]  2673.85  3731.34  5314.10  2925.18  2664.43  4149.60  3674.10  3911.59
# [129]  5509.16  3347.68  4983.80  6365.78  4318.66  3346.71  3516.66  4068.51
# [137]  6158.68 16283.63
#
# $seasonal
# Time Series:
# Start = c(1, 1)
# End = c(3, 34)
# Frequency = 52
#   [1]  -365.42638  -588.71965  1599.12026  -344.69070   -44.09042  1142.89641
#   [7]   201.47016   517.83516   -36.05234  -619.38801 -1182.59138  -702.65522
#  [13] -1255.71311 -1009.88878  -319.52484  -168.55580  -315.69897   282.98497
#  [19]   223.37555  4435.27987 10361.71853  1056.87718   211.52583   599.33103
#  [25]  -589.20542  -626.08167  -734.57340  -791.61051  -559.55349 -1025.40219
#  [31]  -865.76974  -307.83945  -512.00647 -1008.97849  -738.37219  -588.81397
#  [37]  1847.36723  -750.27061  -409.35994   168.76386   296.71031    54.25824
#  [43]  -830.71157  -797.73926  -911.81830  -869.57518  -897.89441  -880.16638
#  [49]  -470.35426  -417.16566    76.01208  -539.26849  -365.42638  -588.71965
#  [55]  1599.12026  -344.69070   -44.09042  1142.89641   201.47016   517.83516
#  [61]   -36.05234  -619.38801 -1182.59138  -702.65522 -1255.71311 -1009.88878
#  [67]  -319.52484  -168.55580  -315.69897   282.98497   223.37555  4435.27987
#  [73] 10361.71853  1056.87718   211.52583   599.33103  -589.20542  -626.08167
#  [79]  -734.57340  -791.61051  -559.55349 -1025.40219  -865.76974  -307.83945
#  [85]  -512.00647 -1008.97849  -738.37219  -588.81397  1847.36723  -750.27061
#  [91]  -409.35994   168.76386   296.71031    54.25824  -830.71157  -797.73926
#  [97]  -911.81830  -869.57518  -897.89441  -880.16638  -470.35426  -417.16566
# [103]    76.01208  -539.26849  -365.42638  -588.71965  1599.12026  -344.69070
# [109]   -44.09042  1142.89641   201.47016   517.83516   -36.05234  -619.38801
# [115] -1182.59138  -702.65522 -1255.71311 -1009.88878  -319.52484  -168.55580
# [121]  -315.69897   282.98497   223.37555  4435.27987 10361.71853  1056.87718
# [127]   211.52583   599.33103  -589.20542  -626.08167  -734.57340  -791.61051
# [133]  -559.55349 -1025.40219  -865.76974  -307.83945  -512.00647 -1008.97849
#
# $trend
# Time Series:
# Start = c(1, 1)
# End = c(3, 34)
# Frequency = 52
#   [1]       NA       NA       NA       NA       NA       NA       NA       NA
#   [9]       NA       NA       NA       NA       NA       NA       NA       NA
#  [17]       NA       NA       NA       NA       NA       NA       NA       NA
#  [25]       NA       NA 2410.207 2419.642 2401.545 2382.395 2395.459 2414.582
#  [33] 2429.186 2457.311 2486.661 2491.770 2491.155 2496.084 2502.382 2502.272
#  [41] 2511.365 2532.900 2560.222 2592.944 2623.290 2687.412 2811.261 2892.454
#  [49] 2896.824 2908.190 2933.063 2954.742 2968.484 2979.442 3000.766 3020.898
#  [57] 3037.832 3056.885 3079.511 3094.219 3096.805 3105.260 3139.344 3172.937
#  [65] 3180.265 3187.901 3214.507 3241.248 3253.071 3265.167 3277.547 3285.142
#  [73] 3293.304 3303.375 3315.396 3334.521 3350.698 3358.454 3375.854 3395.253
#  [81] 3401.336 3411.794 3435.785 3473.931 3515.011 3524.351 3520.808 3544.332
#  [89] 3582.675 3611.341 3632.483 3656.615 3676.018 3688.288 3690.776 3688.540
#  [97] 3706.271 3676.133 3522.882 3413.714 3411.639 3411.376 3436.118 3466.990
# [105] 3497.533 3558.622 3606.368 3628.028 3646.384 3663.267 3699.823 3864.086
# [113]       NA       NA       NA       NA       NA       NA       NA       NA
# [121]       NA       NA       NA       NA       NA       NA       NA       NA
# [129]       NA       NA       NA       NA       NA       NA       NA       NA
# [137]       NA       NA
#
# $random
# Time Series:
# Start = c(1, 1)
# End = c(3, 34)
# Frequency = 52
#   [1]         NA         NA         NA         NA         NA         NA
#   [7]         NA         NA         NA         NA         NA         NA
#  [13]         NA         NA         NA         NA         NA         NA
#  [19]         NA         NA         NA         NA         NA         NA
#  [25]         NA         NA  447.10628  105.96801  -74.85160  194.87710
#  [31]  111.71042   99.64715  -51.35997  515.27782  553.12143  202.81388
#  [37] -750.83194  259.61619  634.28830  263.15383 -334.89579  256.66167
#  [43]  423.78003  212.57570  385.25830  407.89354  170.16325   74.84282
#  [49]  -29.63958 -303.57406  117.79532  138.80686 -370.69756   68.34744
#  [55]  359.98330 -145.12737 -342.28131 -881.59112 -488.94131  850.63619
#  [61]   76.13772   76.13772   76.13772   76.13772   76.13772   76.13772
#  [67]   76.13772   76.13772   76.13772   76.13772   76.13772   76.13772
#  [73]   76.13772   76.13772   76.13772   76.13772   76.13772   76.13772
#  [79] -294.83083   46.30744  227.12705  -42.60165   40.56503   52.62830
#  [85]  203.63542 -363.00237 -400.84598  -50.53843  903.10739 -107.34074
#  [91] -482.01285 -110.87838  487.17123 -104.38622 -271.50458  -60.30026
#  [97] -232.98285 -255.61809  -17.88781   77.43263  181.91503  455.84950
# [103]   34.48013   13.46859  522.97301   83.92801 -207.70785  297.40282
# [109]  494.55676 1033.86657  641.21676 -698.36074         NA         NA
# [115]         NA         NA         NA         NA         NA         NA
# [121]         NA         NA         NA         NA         NA         NA
# [127]         NA         NA         NA         NA         NA         NA
# [133]         NA         NA         NA         NA         NA         NA
#
# $figure
#  [1]  -365.42638  -588.71965  1599.12026  -344.69070   -44.09042  1142.89641
#  [7]   201.47016   517.83516   -36.05234  -619.38801 -1182.59138  -702.65522
# [13] -1255.71311 -1009.88878  -319.52484  -168.55580  -315.69897   282.98497
# [19]   223.37555  4435.27987 10361.71853  1056.87718   211.52583   599.33103
# [25]  -589.20542  -626.08167  -734.57340  -791.61051  -559.55349 -1025.40219
# [31]  -865.76974  -307.83945  -512.00647 -1008.97849  -738.37219  -588.81397
# [37]  1847.36723  -750.27061  -409.35994   168.76386   296.71031    54.25824
# [43]  -830.71157  -797.73926  -911.81830  -869.57518  -897.89441  -880.16638
# [49]  -470.35426  -417.16566    76.01208  -539.26849
#
# $type
# [1] "additive"
#
# attr(,"class")
# [1] "decomposed.ts"

# %%
# Decompose Graficamente
options(repr.plot.width = 20, repr.plot.height = 10)
plot(dec)
# Out:
# plot without title

# %% [markdown]
# ## Average method

# %%
# Previsoes com dados treino, para 5 periodos
# Armazenar previsões
avg_prev <- list()
# loop
for (i in names(ts_train)){
    data <- ts_train[[i]]
    avg_model <- meanf(data,5)
    avg_forecast <- avg_model$mean
    # Arredordar 2 casas decimais
    avg_forecast <- round(avg_forecast, 2)
    avg_prev[[paste(i,'-avg', sep= "")]] <- avg_forecast
}
length(avg_prev)
# Out:
# [1] 63

# %% [markdown]
# Com o average method as previsões de todos os valores futuros são iguais à média (ou “média”) dos dados históricos.

# %%
# Resumo modelo ultima loja
summary(avg_model)
# Out:
# Forecast method: Mean
#
# Model Information:
# $mu
# [1] 371.5003
#
# $mu.se
# [1] 11.54457
#
# $sd
# [1] 135.618
#
# $bootstrap
# [1] FALSE
#
# $call
# meanf(y = data, h = 5)
#
# attr(,"class")
# [1] "meanf"
#
# Error measures:
#                         ME     RMSE      MAE       MPE     MAPE      MASE
# Training set -1.651417e-14 135.1257 95.63221 -11.02004 27.67587 0.7021586
#                   ACF1
# Training set 0.4165589
#
# Forecasts:
#          Point Forecast    Lo 80    Hi 80    Lo 95    Hi 95
# 3.653846       371.5003 196.2251 546.7755 102.3552 640.6454
# 3.673077       371.5003 196.2251 546.7755 102.3552 640.6454
# 3.692308       371.5003 196.2251 546.7755 102.3552 640.6454
# 3.711538       371.5003 196.2251 546.7755 102.3552 640.6454
# 3.730769       371.5003 196.2251 546.7755 102.3552 640.6454

# %%
#Ver Resuiduos ultimo modelo
options(repr.plot.width = 20, repr.plot.height = 10)
checkresiduals(avg_model)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Mean
# Q* = 294.71, df = 28, p-value < 2.2e-16
#
# Model df: 0.   Total lags used: 28
# plot without title

# %%
# Ver previsões
options(repr.plot.width = 20, repr.plot.height = 10)
predict_avg_model <- avg_model
plot(predict_avg_model,
     sub = "mean",
     col = "navyblue",
     lwd = 3)
# Out:
# Plot with title "Forecasts from Mean"

# %%
# Ver dataframe de valores reais
prev <- do.call(rbind, df_test)
# Inserir o nome dos dataframes como uma coluna chamada "Nome"
prev$store_id <- rep(names(df_test), sapply(df_test, nrow))
head(prev)
# Out:
#           store_id date       summed_revenue
# S0002.139 S0002    2019-09-01 4164.56
# S0002.140 S0002    2019-09-08 6267.91
# S0002.141 S0002    2019-09-15 5007.57
# S0002.142 S0002    2019-09-22 3074.56
# S0002.143 S0002    2019-09-29 5728.25
# S0003.282 S0003    2019-09-01 1030.02

# %%
# Criar dataframe com resultados do modelo Average
avg_df <- data.frame(avg_prev)
avg_df <- t(avg_df)
avg_df <- as.data.frame(avg_df)
# Adicionar o índice como coluna
avg_df <- rownames_to_column(avg_df, var = "store_id")
# Transformação para o formato "long"
avg_df <- avg_df %>%
  pivot_longer(cols = -store_id, names_to = "prev", values_to = "revenue")
# Acrescentar as previsões ao dataframe prev
prev$avg_prev <- avg_df$revenue
# Ver 10 linhas aleatórias
head(prev)
# Out:
#           store_id date       summed_revenue avg_prev
# S0002.139 S0002    2019-09-01 4164.56        3262.42
# S0002.140 S0002    2019-09-08 6267.91        3262.42
# S0002.141 S0002    2019-09-15 5007.57        3262.42
# S0002.142 S0002    2019-09-22 3074.56        3262.42
# S0002.143 S0002    2019-09-29 5728.25        3262.42
# S0003.282 S0003    2019-09-01 1030.02         874.90

# %% [markdown]
# ## Naïve method

# %%
# Previsoes com dados treino, para 5 periodos
# Armazenar previsões
naive_prev <- list()
# loop
for (i in names(ts_train)){
    data <- ts_train[[i]]
    naive_model <- naive(data,5)
    naive_forecast <- naive_model$mean 
    #rwf(y, h) # Equivalent alternative
    # Arredordar 2 casas decimais
    naive_forecast <- round(naive_forecast, 2)
    naive_prev[[paste(i,'-naive', sep= "")]] <- naive_forecast
}
length(naive_prev)
# Criar dataframe com resultados do modelo Naive
naive_df <- data.frame(naive_prev)
naive_df <- t(naive_df)
naive_df <- as.data.frame(naive_df)
# Adicionar o índice como coluna
naive_df <- rownames_to_column(naive_df, var = "store_id")
# Transformação para o formato "long"
naive_df <- naive_df %>%
  pivot_longer(cols = -store_id, names_to = "prev", values_to = "revenue")
# Out:
# [1] 63

# %% [markdown]
# Para previsões Naive, simplesmente definimos todas as previsões como o valor da última observação.

# %%
# Resumo modelo ultima loja
summary(naive_model)
# Out:
# Forecast method: Naive method
#
# Model Information:
# Call: naive(y = data, h = 5)
#
# Residual sd: 129.6111
#
# Error measures:
#                    ME     RMSE      MAE       MPE     MAPE      MASE       ACF1
# Training set 6.165109 129.6111 89.38088 -3.646716 23.82664 0.6562596 -0.4059113
#
# Forecasts:
#          Point Forecast     Lo 80    Hi 80    Lo 95    Hi 95
# 3.653846        1169.36 1003.2567 1335.463 915.3269 1423.393
# 3.673077        1169.36  934.4544 1404.266 810.1029 1528.617
# 3.692308        1169.36  881.6606 1457.059 729.3617 1609.358
# 3.711538        1169.36  837.1533 1501.567 661.2938 1677.426
# 3.730769        1169.36  797.9417 1540.778 601.3247 1737.395

# %%
# Ver resuiduos modelo ultima loja da lista
options(repr.plot.width = 20, repr.plot.height = 10)
checkresiduals(naive_model)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Naive method
# Q* = 55.663, df = 28, p-value = 0.001414
#
# Model df: 0.   Total lags used: 28
# plot without title

# %%
# Ver previsões
options(repr.plot.width = 20, repr.plot.height = 10)
predict_naive_model <- naive_model
plot(predict_naive_model,
     sub = "naive",
     col = "navyblue",
     lwd = 3)
# Out:
# Plot with title "Forecasts from Naive method"

# %%
# Ver resultados em tabela prev
prev$naive_prev <- naive_df$revenue
# Ver 10 linhas aleatórias
prev %>% sample_n(10)
# Out:
#            store_id date       summed_revenue avg_prev naive_prev
# S0003.282  S0003    2019-09-01 1030.02         874.90   5802.04
# S0094.5981 S0094    2019-09-15 6713.85        3442.49  11205.97
# S0142.8154 S0142    2019-09-01 1237.43        1379.17   8763.13
# S0055.3282 S0055    2019-09-15 1600.22        1325.66   3996.16
# S0132.7754 S0132    2019-09-22 2999.80        2104.17  14046.02
# S0045.2769 S0045    2019-09-01  638.90         715.03   2248.80
# S0089.5633 S0089    2019-09-08  485.59         314.91   1481.45
# S0142.8157 S0142    2019-09-22 1794.39        1379.17   8763.13
# S0131.7611 S0131    2019-09-22 1546.06        1268.94   7161.03
# S0005.372  S0005    2019-09-22 1130.89        1171.28   5940.84

# %% [markdown]
# ## Seasonal naïve method

# %%
# Previsoes com dados treino, para 5 periodos
# Armazenar previsões
snaive_prev <- list()
# loop
for (i in names(ts_train)) {
  data <- ts_train[[i]]
  # Tentar executar a previsão e lidar com erros
  snaive_forecast <- tryCatch(
    snaive(data, 5)$mean,
    error = function(e) {
      NaN 
    }
  )
  snaive_prev[[paste(i, '-snaive', sep = "")]] <- snaive_forecast
}
# Criar dataframe com resultados do modelo Snaive
snaive_df <- data.frame(snaive_prev)
snaive_df <- t(snaive_df)
snaive_df <- as.data.frame(snaive_df)
# Adicionar o índice como coluna
snaive_df <- rownames_to_column(snaive_df, var = "store_id")
# Transformação para o formato "long"
snaive_df <- snaive_df %>%
  pivot_longer(cols = -store_id, names_to = "prev", values_to = "revenue")
length(snaive_prev)
# Out:
# [1] 63

# %% [markdown]
# Neste caso, definimos cada previsão para ser igual ao último valor observado da mesma estação (por exemplo, o mesma semana do ano anterior).

# %%
# Resumo modelo loja S0062
summary(snaive(ts_train[['S0062']]), 5)
# Out:
# Forecast method: Seasonal naive method
#
# Model Information:
# Call: snaive(y = ts_train[["S0062"]])
#
# Residual sd: 4621.0189
#
# Error measures:
#                    ME     RMSE      MAE      MPE     MAPE MASE      ACF1
# Training set 2298.086 4621.019 3041.201 19.49865 27.58381    1 0.2879481
#
# Forecasts:
#          Point Forecast       Lo 80    Hi 80      Lo 95    Hi 95
# 3.653846        6609.09   687.01601 12531.16 -2447.9406 15666.12
# 3.673077        8156.60  2234.52601 14078.67  -900.4306 17213.63
# 3.692308       15522.13  9600.05601 21444.20  6465.0994 24579.16
# 3.711538        7732.91  1810.83601 13654.98 -1324.1206 16789.94
# 3.730769        8404.39  2482.31601 14326.46  -652.6406 17461.42
# 3.750000       10215.95  4293.87601 16138.02  1158.9194 19272.98
# 3.769231       10237.69  4315.61601 16159.76  1180.6594 19294.72
# 3.788462        9725.77  3803.69601 15647.84   668.7394 18782.80
# 3.807692        8243.10  2321.02601 14165.17  -813.9306 17300.13
# 3.826923        8924.07  3001.99601 14846.14  -132.9606 17981.10
# 3.846154        8727.20  2805.12601 14649.27  -329.8306 17784.23
# 3.865385       10638.84  4716.76601 16560.91  1581.8094 19695.87
# 3.884615        9543.94  3621.86601 15466.01   486.9094 18600.97
# 3.903846       10510.16  4588.08601 16432.23  1453.1294 19567.19
# 3.923077        9727.95  3805.87601 15650.02   670.9194 18784.98
# 3.942308       10476.68  4554.60601 16398.75  1419.6494 19533.71
# 3.961538       10882.73  4960.65601 16804.80  1825.6994 19939.76
# 3.980769       13511.26  7589.18601 19433.33  4454.2294 22568.29
# 4.000000       10955.10  5033.02601 16877.17  1898.0694 20012.13
# 4.019231       10536.13  4614.05601 16458.20  1479.0994 19593.16
# 4.038462       20225.25 14303.17601 26147.32 11168.2194 29282.28
# 4.057692       11615.43  5693.35601 17537.50  2558.3994 20672.46
# 4.076923       11509.49  5587.41601 17431.56  2452.4594 20566.52
# 4.096154       14606.57  8684.49601 20528.64  5549.5394 23663.60
# 4.115385       10715.48  4793.40601 16637.55  1658.4494 19772.51
# 4.134615        9534.14  3612.06601 15456.21   477.1094 18591.17
# 4.153846       11431.83  5509.75601 17353.90  2374.7994 20488.86
# 4.173077       12691.13  6769.05601 18613.20  3634.0994 21748.16
# 4.192308       10481.04  4558.96601 16403.11  1424.0094 19538.07
# 4.211538       10386.36  4464.28601 16308.43  1329.3294 19443.39
# 4.230769       10978.76  5056.68601 16900.83  1921.7294 20035.79
# 4.250000       10091.11  4169.03601 16013.18  1034.0794 19148.14
# 4.269231       11537.73  5615.65601 17459.80  2480.6994 20594.76
# 4.288462       11102.55  5180.47601 17024.62  2045.5194 20159.58
# 4.307692        8615.78  2693.70601 14537.85  -441.2506 17672.81
# 4.326923        9109.92  3187.84601 15031.99    52.8894 18166.95
# 4.346154       10758.89  4836.81601 16680.96  1701.8594 19815.92
# 4.365385        9740.17  3818.09601 15662.24   683.1394 18797.20
# 4.384615        9516.50  3594.42601 15438.57   459.4694 18573.53
# 4.403846        9401.13  3479.05601 15323.20   344.0994 18458.16
# 4.423077        6058.47   136.39601 11980.54 -2998.5606 15115.50
# 4.442308        8969.68  3047.60601 14891.75   -87.3506 18026.71
# 4.461538       13764.04  7841.96601 19686.11  4707.0094 22821.07
# 4.480769        8178.80  2256.72601 14100.87  -878.2306 17235.83
# 4.500000        8706.48  2784.40601 14628.55  -350.5506 17763.51
# 4.519231        9072.94  3150.86601 14995.01    15.9094 18129.97
# 4.538462        8718.53  2796.45601 14640.60  -338.5006 17775.56
# 4.557692        6907.79   985.71601 12829.86 -2149.2406 15964.82
# 4.576923        8148.93  2226.85601 14071.00  -908.1006 17205.96
# 4.596154        7227.03  1304.95601 13149.10 -1830.0006 16284.06
# 4.615385       15734.29  9812.21601 21656.36  6677.2594 24791.32
# 4.634615       30984.55 25062.47601 36906.62 21927.5194 40041.58
# 4.653846        6609.09 -1765.98736 14984.17 -6199.4855 19417.67
# 4.673077        8156.60  -218.47736 16531.68 -4651.9755 20965.18
# 4.692308       15522.13  7147.05264 23897.21  2713.5545 28330.71
# 4.711538        7732.91  -642.16736 16107.99 -5075.6655 20541.49
# 4.730769        8404.39    29.31264 16779.47 -4404.1855 21212.97
# 4.750000       10215.95  1840.87264 18591.03 -2592.6255 23024.53
# 4.769231       10237.69  1862.61264 18612.77 -2570.8855 23046.27
# 4.788462        9725.77  1350.69264 18100.85 -3082.8055 22534.35
# 4.807692        8243.10  -131.97736 16618.18 -4565.4755 21051.68
# 4.826923        8924.07   548.99264 17299.15 -3884.5055 21732.65
# 4.846154        8727.20   352.12264 17102.28 -4081.3755 21535.78
# 4.865385       10638.84  2263.76264 19013.92 -2169.7355 23447.42
# 4.884615        9543.94  1168.86264 17919.02 -3264.6355 22352.52
# 4.903846       10510.16  2135.08264 18885.24 -2298.4155 23318.74
# 4.923077        9727.95  1352.87264 18103.03 -3080.6255 22536.53
# 4.942308       10476.68  2101.60264 18851.76 -2331.8955 23285.26
# 4.961538       10882.73  2507.65264 19257.81 -1925.8455 23691.31
# 4.980769       13511.26  5136.18264 21886.34   702.6845 26319.84
# 5.000000       10955.10  2580.02264 19330.18 -1853.4755 23763.68
# 5.019231       10536.13  2161.05264 18911.21 -2272.4455 23344.71
# 5.038462       20225.25 11850.17264 28600.33  7416.6745 33033.83
# 5.057692       11615.43  3240.35264 19990.51 -1193.1455 24424.01
# 5.076923       11509.49  3134.41264 19884.57 -1299.0855 24318.07
# 5.096154       14606.57  6231.49264 22981.65  1797.9945 27415.15
# 5.115385       10715.48  2340.40264 19090.56 -2093.0955 23524.06
# 5.134615        9534.14  1159.06264 17909.22 -3274.4355 22342.72
# 5.153846       11431.83  3056.75264 19806.91 -1376.7455 24240.41
# 5.173077       12691.13  4316.05264 21066.21  -117.4455 25499.71
# 5.192308       10481.04  2105.96264 18856.12 -2327.5355 23289.62
# 5.211538       10386.36  2011.28264 18761.44 -2422.2155 23194.94
# 5.230769       10978.76  2603.68264 19353.84 -1829.8155 23787.34
# 5.250000       10091.11  1716.03264 18466.19 -2717.4655 22899.69
# 5.269231       11537.73  3162.65264 19912.81 -1270.8455 24346.31
# 5.288462       11102.55  2727.47264 19477.63 -1706.0255 23911.13
# 5.307692        8615.78   240.70264 16990.86 -4192.7955 21424.36
# 5.326923        9109.92   734.84264 17485.00 -3698.6555 21918.50
# 5.346154       10758.89  2383.81264 19133.97 -2049.6855 23567.47
# 5.365385        9740.17  1365.09264 18115.25 -3068.4055 22548.75
# 5.384615        9516.50  1141.42264 17891.58 -3292.0755 22325.08
# 5.403846        9401.13  1026.05264 17776.21 -3407.4455 22209.71
# 5.423077        6058.47 -2316.60736 14433.55 -6750.1055 18867.05
# 5.442308        8969.68   594.60264 17344.76 -3838.8955 21778.26
# 5.461538       13764.04  5388.96264 22139.12   955.4645 26572.62
# 5.480769        8178.80  -196.27736 16553.88 -4629.7755 20987.38
# 5.500000        8706.48   331.40264 17081.56 -4102.0955 21515.06
# 5.519231        9072.94   697.86264 17448.02 -3735.6355 21881.52
# 5.538462        8718.53   343.45264 17093.61 -4090.0455 21527.11
# 5.557692        6907.79 -1467.28736 15282.87 -5900.7855 19716.37
# 5.576923        8148.93  -226.14736 16524.01 -4659.6455 20957.51
# 5.596154        7227.03 -1148.04736 15602.11 -5581.5455 20035.61
# 5.615385       15734.29  7359.21264 24109.37  2925.7145 28542.87
# 5.634615       30984.55 22609.47264 39359.63 18175.9745 43793.13

# %%
#Ver Resuiduos modelo ultima loja da lista
options(repr.plot.width = 20, repr.plot.height = 10)
checkresiduals(snaive(ts_train[['S0062']], 5))
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Seasonal naive method
# Q* = 29.646, df = 28, p-value = 0.3803
#
# Model df: 0.   Total lags used: 28
# plot without title

# %%
# Ver previsões
options(repr.plot.width = 20, repr.plot.height = 10)
predict_naive_model <- snaive(ts_train[['S0062']], 5)
plot(predict_naive_model,
     sub = "snaice",
     col = "navyblue",
     lwd = 3)
# Out:
# Plot with title "Forecasts from Seasonal naive method"

# %%
# Ver resultados em tabela prev
prev$snaive_prev <- snaive_df$revenue
# Ver 10 linhas aleatórias
prev %>% sample_n(10)
# Out:
#            store_id date       summed_revenue avg_prev naive_prev snaive_prev
# S0039.2343 S0039    2019-09-22  632.01         536.78   2320.69    674.93
# S0142.8157 S0142    2019-09-22 1794.39        1379.17   8763.13   1422.84
# S0071.4268 S0071    2019-09-29 2190.63        1762.15   4084.09   1598.58
# S0030.1829 S0030    2019-09-22  667.16         308.95   1406.81    330.59
# S0073.4551 S0073    2019-09-08 1761.06         902.40   4028.34    828.18
# S0022.1399 S0022    2019-09-15 2268.27        1815.45   4224.28   1734.66
# S0040.2483 S0040    2019-09-01 3278.88        3364.72  12070.80   3009.89
# S0007.399  S0007    2019-09-22  946.83         785.58   1732.74       NaN
# S0109.7038 S0109    2019-09-15 1425.80        1164.72   5009.27       NaN
# S0022.1397 S0022    2019-09-01 1764.53        1815.45   4224.28   1351.98

# %% [markdown]
# ## Random Walk with Drift (RWD)

# %%
# Modelo Random Walk with Drift (RWD).
# Previsoes com dados treino, para 5 periodos
# Armazenar previsões
rwf_prev <- list()
# loop
for (i in names(ts_train)){
    data <- ts_train[[i]]
    rwf_model <- rwf(data,5, drift = TRUE)
    rwf_forecast<- rwf_model$mean
    # Arredordar 2 casas decimais
    rwf_forecast <- round(rwf_forecast, 2)
    rwf_prev[[paste(i,'-rws', sep= "")]] <- rwf_forecast
}
length(rwf_prev)
# Criar dataframe com resultados do modelo Naive
rwf_df <- data.frame(rwf_prev)
rwf_df <- t(rwf_df)
rwf_df <- as.data.frame(rwf_df)
# Adicionar o índice como coluna
rwf_df <- rownames_to_column(rwf_df, var = "store_id")
# Transformação para o formato "long"
rwf_df <- rwf_df %>%
  pivot_longer(cols = -store_id, names_to = "prev", values_to = "revenue")
#rwf_forecast <- rwf(ts_cut, 5, drift=TRUE)
#rwf_forecast$mean
# Out:
# [1] 63

# %% [markdown]
# Drift method 'e uma variação do método Naive é permitir que as previsões aumentem ou diminuam ao longo do tempo, onde a quantidade de mudança ao longo do tempo (chamada de desvio ) é definida como a mudança média observada nos dados históricos.
#
# Isso equivale a traçar uma linha entre a primeira e a última observação e extrapolá-la para o futuro.

# %%
# Resumo modelo loja exemplo
summary(rwf_model)
# Out:
# Forecast method: Random walk with drift
#
# Model Information:
# Call: rwf(y = data, h = 5, drift = TRUE)
#
# Drift: 6.1651  (se 11.1015)
# Residual sd: 129.9395
#
# Error measures:
#                        ME     RMSE      MAE       MPE     MAPE      MASE
# Training set 5.804765e-15 129.4644 89.58924 -5.488702 24.07119 0.6577895
#                    ACF1
# Training set -0.4059113
#
# Forecasts:
#          Point Forecast     Lo 80    Hi 80    Lo 95    Hi 95
# 3.653846       1175.525 1008.3943 1342.656 919.9206 1431.130
# 3.673077       1181.690  944.4767 1418.904 818.9035 1544.477
# 3.692308       1187.855  896.2861 1479.425 741.9387 1633.772
# 3.711538       1194.020  856.1450 1531.896 677.2846 1710.756
# 3.730769       1200.186  821.0922 1579.279 620.4123 1779.959

# %%
#Ver Resuiduos modelo ultima loja da lista
options(repr.plot.width = 20, repr.plot.height = 10)
checkresiduals(rwf_model)
# Out:
# 	Ljung-Box test
#
# data:  Residuals from Random walk with drift
# Q* = 55.663, df = 28, p-value = 0.001414
#
# Model df: 0.   Total lags used: 28
# plot without title

# %%
# Ver previsões
options(repr.plot.width = 20, repr.plot.height = 10)
predict_naive_model <- rwf_model
plot(predict_naive_model,
     sub = "RWF",
     col = "navyblue",
     lwd = 3)
# Out:
# Plot with title "Forecasts from Random walk with drift"

# %%
# Ver resultados em tabela prev
prev$rwf_prev <- rwf_df$revenue
# Ver 10 linhas aleatórias
prev %>% sample_n(10)
# Out:
#            store_id date       summed_revenue avg_prev naive_prev snaive_prev
# S0122.7325 S0122    2019-09-22  1389.52        1162.85  4562.26    1399.93
# S0039.2342 S0039    2019-09-15   627.13         536.78  2320.69     722.61
# S0131.7611 S0131    2019-09-22  1546.06        1268.94  7161.03    1317.92
# S0143.8301 S0143    2019-09-29   704.87         371.50  1169.36     383.06
# S0010.539  S0010    2019-09-01  2947.91        2409.83  8302.20    2317.25
# S0026.1687 S0026    2019-09-29 12256.18        8756.18 37185.47    8858.60
# S0014.826  S0014    2019-09-08  1389.82         984.43  2727.56    1164.01
# S0126.7469 S0126    2019-09-29  5058.87        2866.36  7940.42    2344.09
# S0085.5204 S0085    2019-09-08 23264.68       14349.46 41291.57   14388.11
# S0122.7323 S0122    2019-09-08  1992.27        1162.85  4562.26    1020.60
#            rwf_prev
# S0122.7325  4674.97
# S0039.2342  2358.52
# S0131.7611  7348.44
# S0143.8301  1200.19
# S0010.539   8344.73
# S0026.1687 38335.02
# S0014.826   2752.88
# S0126.7469  8142.21
# S0085.5204 41772.23
# S0122.7323  4618.62

# %%
# Fazer uma média de todos os modelos
prev$avg_models <-round(rowMeans(prev[, -(1:3)], na.rm = TRUE),2)
# ver dataframe final
head(prev,10)
# Out:
#           store_id date       summed_revenue avg_prev naive_prev snaive_prev
# S0002.139 S0002    2019-09-01 4164.56        3262.42  16283.63   2381.59
# S0002.140 S0002    2019-09-08 6267.91        3262.42  16283.63   2904.98
# S0002.141 S0002    2019-09-15 5007.57        3262.42  16283.63   6333.15
# S0002.142 S0002    2019-09-22 3074.56        3262.42  16283.63   2753.73
# S0002.143 S0002    2019-09-29 5728.25        3262.42  16283.63   2741.11
# S0003.282 S0003    2019-09-01 1030.02         874.90   5802.04    738.28
# S0003.283 S0003    2019-09-08 1302.61         874.90   5802.04    884.21
# S0003.284 S0003    2019-09-15 1255.40         874.90   5802.04   2603.89
# S0003.285 S0003    2019-09-22 1343.15         874.90   5802.04    921.47
# S0003.286 S0003    2019-09-29 1215.74         874.90   5802.04   1009.48
#           rwf_prev avg_models
# S0002.139 16389.25  9579.22
# S0002.140 16494.88  9736.48
# S0002.141 16600.50 10619.92
# S0002.142 16706.12  9751.48
# S0002.143 16811.75  9774.73
# S0003.282  5840.40  3313.90
# S0003.283  5878.76  3359.98
# S0003.284  5917.13  3799.49
# S0003.285  5955.49  3388.48
# S0003.286  5993.85  3420.07

# %% [markdown]
# ### ***Os métodos simples anteriores servem como referência para escolher um melhor que terá de apresentar melhores resultados.***

# %% [markdown]
# ## Visualização de previsões e dados reais

# %%
# Ver graficamente as previsões para 3 lojas
options(repr.plot.width = 20, repr.plot.height = 9)

for (i in 1:length(ts_train)) {
  ts_name <- names(ts_train)[i]
  ts <- ts_train[[ts_name]]
  
  if (i <= 3) {
    plot <- autoplot(ts_real[[i]]) +
      autolayer(avg_prev[[i]], series = "Mean") +
      autolayer(naive_prev[[i]], series = "Naïve") +
      autolayer(snaive_prev[[i]], series = "Seasonal naïve") +
      autolayer(rwf_prev[[i]], series = "Drift") +
      ggtitle(paste("Forecasts Revenue to Store : ",ts_name))+
      xlab("Weeks") + ylab("Lira") +
      guides(colour=guide_legend(title="Forecast"))
      
    print(plot)
  }
}
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# Pela visualização dos graficos conseguimos perceber que dependendo da loja existem modelos que podem fazer sentido e outros que não.

# %% [markdown]
# ## Evaluation

# %%
# Criar dataframe para armazenar as métricas de accuracy

# Criar listas de dataframes com resultados para cada store
prev_list <- list() 
# criar variável com lista das lojas unicas
stores <- unique(prev$store_id)
# Loop para criar os dataframes separados
for (store in stores) {
  # filtrar dataframe
  df_store_prev <- prev[prev$store_id == store,]
  # Adicionar dataframe à lista
  prev_list[[store]] <- df_store_prev
}
# metricas avg
accuracy_list_avg <- list()
# Calcular a accuracy para modelos ets
for (ts in names(prev_list)) {

      # Obter os valores reais
      real_values <- prev_list[[ts]]$summed_revenue

      # Obter as previsões
      predicts <- prev_list[[ts]]$avg_prev

      # Calcular a accuracy
      accuracy <- accuracy(real_values, predicts)

      # Armazenar as métricas de accuracy na lista
      accuracy_list_avg[[ts]] <- accuracy
}
# metricas naive
accuracy_list_naive <- list()
# Calcular a accuracy para modelos ets
for (ts in names(prev_list)) {

      # Obter os valores reais
      real_values <- prev_list[[ts]]$summed_revenue

      # Obter as previsões
      predicts <- prev_list[[ts]]$naive_prev

      # Calcular a accuracy
      accuracy <- accuracy(real_values, predicts)

      # Armazenar as métricas de accuracy na lista
      accuracy_list_naive[[ts]] <- accuracy
}
# metricas snaive
accuracy_list_snaive <- list()
# Calcular a accuracy para modelos ets
for (ts in names(prev_list)) {

      # Obter os valores reais
      real_values <- prev_list[[ts]]$summed_revenue

      # Obter as previsões
      predicts <- prev_list[[ts]]$snaive_prev

      # Calcular a accuracy
      accuracy <- accuracy(real_values, predicts)

      # Armazenar as métricas de accuracy na lista
      accuracy_list_snaive[[ts]] <- accuracy
}
# metricas rwf
accuracy_list_rwf <- list()
# Calcular a accuracy para modelos ets
for (ts in names(prev_list)) {

      # Obter os valores reais
      real_values <- prev_list[[ts]]$summed_revenue

      # Obter as previsões
      predicts <- prev_list[[ts]]$rwf_prev

      # Calcular a accuracy
      accuracy <- accuracy(real_values, predicts)

      # Armazenar as métricas de accuracy na lista
      accuracy_list_rwf[[ts]] <- accuracy
}
# metricas avg_models
accuracy_list_avgmodels <- list()
# Calcular a accuracy para modelos ets
for (ts in names(prev_list)) {

      # Obter os valores reais
      real_values <- prev_list[[ts]]$summed_revenue

      # Obter as previsões
      predicts <- prev_list[[ts]]$avg_models

      # Calcular a accuracy
      accuracy <- accuracy(real_values, predicts)

      # Armazenar as métricas de accuracy na lista
      accuracy_list_avgmodels[[ts]] <- accuracy
}
# Converter as lista de accuracy em um DataFrame
df_accuracy_avg <- do.call(rbind, accuracy_list_avg)
df_accuracy_naive <- do.call(rbind, accuracy_list_naive)
df_accuracy_snaive <- do.call(rbind, accuracy_list_snaive)
df_accuracy_rwf <- do.call(rbind, accuracy_list_rwf)
df_accuracy_avgmodels <- do.call(rbind, accuracy_list_avgmodels)
# Adicionar coluna "store_id" com os valores 
df_accuracy_avg <- cbind(store_id = names(prev_list), df_accuracy_avg)
df_accuracy_naive <- cbind(store_id = names(prev_list), df_accuracy_naive)
df_accuracy_snaive <- cbind(store_id = names(prev_list), df_accuracy_snaive)
df_accuracy_rwf <- cbind(store_id = names(prev_list), df_accuracy_rwf)
df_accuracy_avgmodels <- cbind(store_id = names(prev_list), df_accuracy_avgmodels)
# Criar dataframes
df_accuracy_avg <- as.data.frame(df_accuracy_avg, row.names = NULL)
df_accuracy_naive <- as.data.frame(df_accuracy_naive, row.names = NULL)
df_accuracy_snaive <- as.data.frame(df_accuracy_snaive, row.names = NULL)
df_accuracy_rwf <- as.data.frame(df_accuracy_rwf, row.names = NULL)
df_accuracy_avgmodels <- as.data.frame(df_accuracy_avgmodels, row.names = NULL)
# Adicionar sufixo  colunas
colnames(df_accuracy_avg)[-1] <- paste(colnames(df_accuracy_avg)[-1], "_avg", sep = "")
colnames(df_accuracy_naive)[-1] <- paste(colnames(df_accuracy_naive)[-1], "_naive", sep = "")
colnames(df_accuracy_snaive)[-1] <- paste(colnames(df_accuracy_snaive)[-1], "_snaive", sep = "")
colnames(df_accuracy_rwf)[-1] <- paste(colnames(df_accuracy_rwf)[-1], "_rwf", sep = "")
colnames(df_accuracy_avgmodels)[-1] <- paste(colnames(df_accuracy_avgmodels)[-1], "_avgmodels", sep = "")
# Merge dataframes
df_combined <- Reduce(function(x, y) merge(x, y, by = "store_id"), 
                      list(df_accuracy_avg, df_accuracy_naive, df_accuracy_snaive, 
                           df_accuracy_rwf, df_accuracy_avgmodels))
head(df_combined)
# Out:
#   store_id ME_avg            RMSE_avg         MAE_avg  MPE_avg
# 1 S0002    -1586.15          1949.76840730893 1661.294 -48.6188167066165
# 2 S0003    -354.484          370.731244056931 354.484  -40.517087667162
# 3 S0005    -9.91800000000003 66.6703623808961 58.45    -0.846765931288849
# 4 S0007    -107.19           164.806417654168 147.086  -13.644695638891
# 5 S0010    -473.092          646.007949115179 537.96   -19.6317582568065
# 6 S0012    -399.828          488.364802417209 399.828  -29.9611087381696
#   MAPE_avg         ME_naive RMSE_naive       MAE_naive MPE_naive        ⋯
# 1 50.9221375543308 11435.06 11491.1410322578 11435.06  70.2242681760762 ⋯
# 2 40.517087667162  4572.656 4573.94421078788 4572.656  78.8111767585194 ⋯
# 3 4.99026705826105 4759.642 4760.09858497279 4759.642  80.1173234761414 ⋯
# 4 18.7232363349372 839.97   849.247349186325 839.97    48.4764015374494 ⋯
# 5 22.3235663926501 5419.278 5437.10256213178 5419.278  65.275204162752  ⋯
# 6 29.9611087381696 4096.722 4106.30842679164 4096.722  70.2571410931841 ⋯
#   ME_rwf   RMSE_rwf         MAE_rwf  MPE_rwf          MAPE_rwf
# 1 11751.93 11807.5686510433 11751.93 70.7897390009482 70.7897390009482
# 2 4687.742 4688.63832274361 4687.742 79.2306689682782 79.2306689682782
# 3 4979.672 4980.53539916744 4979.672 80.830465524004  80.830465524004
# 4 1016.48  1019.83804061233 1016.48  53.3627646320438 53.3627646320438
# 5 5546.866 5563.32391492892 5546.866 65.8089360319888 65.8089360319888
# 6 4206.582 4215.857407202   4206.582 70.8097548012328 70.8097548012328
#   ME_avgmodels RMSE_avgmodels   MAE_avgmodels MPE_avgmodels    MAPE_avgmodels
# 1 5043.796     5173.06977257798 5043.796      50.9730236376107 50.9730236376107
# 2 2227         2234.44483741264 2227          64.3845176481248 64.3845176481248
# 3 2725.122     2782.70742095176 2725.122      69.1728184437976 69.1728184437976
# 4 583.086      592.602325425745 583.086       39.6064787571878 39.6064787571878
# 5 2499.78      2537.02940269127 2499.78       46.4512761399268 46.4512761399268
# 6 1962.162     1975.93300867717 1962.162      53.1732552232256 53.1732552232256

# %%
# Exportar resultados
# Accuracy dataframe
path <- file.path("C:", "Users", "Egomes", "Desktop", "PG_Analytics_Data_science_empresarial", "Isla_gaia", "14-ProjetoII", "projetoII", "dataStaging", "accuracySimpleMethods.csv")
write.csv(df_combined, file = path, row.names = FALSE)
# Resultado previsões em dados teste
path <- file.path("C:", "Users", "Egomes", "Desktop", "PG_Analytics_Data_science_empresarial", "Isla_gaia", "14-ProjetoII", "projetoII", "dataStaging", "resultSimpleMethods.csv")
write.csv(prev, file = path, row.names = FALSE)
print('Exportação concluida!')
# Out:
# [1] "Exportação concluida!"
